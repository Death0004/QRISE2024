# %%
# POWER METHOD

import numpy as np
from scipy.linalg import eigh

def run_GSE(rho, H, observable, m=1):
    def normalize_density_matrix(rho):
        """Normalize the density matrix to have a trace of 1 and non-negative eigenvalues."""
        trace_rho = np.trace(rho)
        if trace_rho == 0:
            raise ValueError("Trace of density matrix rho is zero, cannot normalize.")
        eigenvalues, eigenvectors = np.linalg.eigh(rho)
        eigenvalues_clipped = np.clip(eigenvalues, 0, None)
        return eigenvectors @ np.diag(eigenvalues_clipped) @ np.conj(eigenvectors.T)

    rho_normalized = normalize_density_matrix(rho)
    
    def is_valid_density_matrix(rho_normalized):
        """Check if rho matrix is a valid density matrix."""
        return np.allclose(np.trace(rho_normalized), 1) and np.all(np.linalg.eigvals(rho) >= 0)

    if not is_valid_density_matrix(rho_normalized):
        raise ValueError("The normalized rho is still not a valid density matrix.")
    
    def is_hermitian(matrix):
        """Check if a matrix is Hermitian."""
        return np.allclose(matrix, matrix.conj().T)
    
    if not is_hermitian(H_matrix):
        raise ValueError("H_matrix is not Hermitian.")


    A = rho_normalized if m % 2 != 0 else np.eye(rho_normalized.shape[0])
    powers_of_rho_normalized = [np.linalg.matrix_power(rho_normalized, i) for i in range(m + 1)]
    

    #H_MATRIX NEEDS TO BE PASSED!!!

    H_matrix = np.zeros((m+1, m+1), dtype=np.complex128)

    S_matrix = np.zeros((m+1, m+1), dtype=np.complex128)

    for i in range(m + 1):
        for j in range(m + 1):
            sigma_i = powers_of_rho_normalized[i].conj().T
            sigma_j = powers_of_rho_normalized[j]
            H_matrix[i, j] = np.trace(sigma_i @ A @ sigma_j @ H)
            S_matrix[i, j] = np.trace(sigma_i @ A @ sigma_j)

    eigenvalues, eigenvectors = eigh(H_matrix, S_matrix)
    min_eigenvalue_index = np.argmin(eigenvalues)
    alpha = eigenvectors[:, min_eigenvalue_index]
    rho_EM = sum(alpha[i] * powers_of_rho_normalized[i] for i in range(m + 1))
    expectation_value = np.real(np.trace(rho_EM @ observable))
    
    return expectation_value

# %%
import numpy as np
from scipy.linalg import eigh

def run_GSE_power_subspace(rho, H, observable, max_power=0):
    """
    Run the GSE using a power subspace approach for each power up to max_power.

    Parameters:
    - rho: numpy.ndarray, the density matrix of the system.
    - H: numpy.ndarray, the system Hamiltonian.
    - observable: numpy.ndarray, the observable for which the expectation value is calculated.
    - max_power: int, the highest power of rho used to construct the subspace.

    Returns: 
    - A dictionary with keys being the power and values being the expectation value for each power.
    """
    def normalize_density_matrix(rho):
        """Normalize the density matrix to have a trace of 1 and non-negative eigenvalues."""
        trace_rho = np.trace(rho)
        if trace_rho == 0:
            raise ValueError("Trace of density matrix rho is zero, cannot normalize.")
        eigenvalues, eigenvectors = np.linalg.eigh(rho)
        eigenvalues_clipped = np.clip(eigenvalues, 0, None)
        return eigenvectors @ np.diag(eigenvalues_clipped) @ np.conj(eigenvectors.T)

    rho_normalized = normalize_density_matrix(rho)
    results = {}

    def is_valid_density_matrix(rho_normalized):
        """Check if rho matrix is a valid density matrix."""
        return np.allclose(np.trace(rho_normalized), 1) and np.all(np.linalg.eigvals(rho) >= 0)

    if not is_valid_density_matrix(rho_normalized):
        raise ValueError("The normalized rho is still not a valid density matrix.")
    
    def is_hermitian(matrix):
        """Check if a matrix is Hermitian."""
        return np.allclose(matrix, matrix.conj().T)
    
    if not is_hermitian(H):
        raise ValueError("H_matrix is not Hermitian.")

    for m in range(max_power + 1):
        # Generate powers of rho up to m
        powers_of_rho_normalized = [np.linalg.matrix_power(rho_normalized, i) for i in range(m + 1)]
        A = rho_normalized if m % 2 != 0 else np.eye(rho_normalized.shape[0])
        
        # Initialize Hamiltonian and Overlap matrices
        H_matrix = np.zeros((m+1, m+1), dtype=np.complex128)
        S_matrix = np.zeros((m+1, m+1), dtype=np.complex128)

        # Build the H and S matrices for subspace defined by powers up to m
        for i in range(m+1):
            for j in range(m+1):
                sigma_i = powers_of_rho_normalized[i].conj().T
                sigma_j = powers_of_rho_normalized[j]
                H_matrix[i, j] = np.trace(sigma_i @ A @ sigma_j @ H)
                S_matrix[i, j] = np.trace(sigma_i @ A @ sigma_j)

        #REGULARIZE S SUBSPACE
        epsilon = 1e-10
        np.fill_diagonal(S_matrix, np.diagonal(S_matrix) + epsilon)

        # Solve the generalized eigenvalue problem for this subspace
        eigenvalues, eigenvectors = eigh(H_matrix, S_matrix)
        min_eigenvalue_index = np.argmin(eigenvalues)
        optimal_alpha = eigenvectors[:, min_eigenvalue_index]

        # Construct the error-mitigated density matrix
        rho_EM = sum(optimal_alpha[k] * powers_of_rho_normalized[k] for k in range(m+1))
        expectation_value = np.real(np.trace(rho_EM @ observable))

        # Store the results for each power
        results[m] = expectation_value

    # Parse results to find the best result
    best_power = min(results, key=lambda k: abs(results[k]))
    best_expectation_value = results[best_power]
    print(f"Best result obtained for power {best_power}: {best_expectation_value}")
    return results


# Example usage
rho = np.array([[0.7, 0.3], [0.3, 0.3]])  # Example density matrix
H = np.array([[1, 0], [0, 0]])  # Example Hamiltonian
observable = np.array([[1, 0], [0, 0]])  # Example observable
max_power = 24 # Example to calculate using powers up to rho^2

results = run_GSE_power_subspace(rho, H, observable, max_power)
print(results)
# Out:
# Best result obtained for power 6: 0.0
# {0: 0.7071067811688698, 1: 0.5962401709236329, 2: 7.275957614183426e-12, 3: 1.4551915228366852e-11, 4: -7.275957614183426e-12, 5: 2.2737367544323206e-11, 6: 0.0, 7: 9.094947017729282e-12, 8: -9.094947017729282e-13, 9: -1.0231815394945443e-12, 10: 9.094947017729282e-13, 11: -1.8616219676914625e-12, 12: 0.0, 13: -2.2737367544323206e-12, 14: 4.547473508864641e-12, 15: -3.1823432777855487e-12, 16: -1.0302869668521453e-11, 17: 1.4381384971784428e-11, 18: -5.8832938520936295e-12, 19: -2.8883562208648073e-12, 20: 6.30961949354969e-12, 21: 1.971756091734278e-12, 22: 8.952838470577262e-13, 23: 1.0231815394945443e-12, 24: 4.61142235508305e-12}

# %%
#FAULT SUBSPACE METHOD

import numpy as np
from scipy.linalg import eigh

def run_GSE_fault_subspace(rho, H, observable, noise_levels, noise_function, stretch_factor=1.0, regularization_factor=1e-5):
    """
    Run the GSE using a fault subspace approach with a customizable noise function and identity matrix A.

    Parameters:
    - rho: numpy.ndarray, the density matrix of the system.
    - H_matrix: numpy.ndarray, the system Hamiltonian.
    - observable: numpy.ndarray, the observable for which the expectation value is calculated.
    - noise_levels: list defining the noise levels or generating them dynamically.
    - noise_function: a function that applies noise to rho given noise levels.
    - stretch_factor: float, a factor to scale the noise levels, simulating stronger or weaker noise.
    - regularization_factor: float, a small value added to the diagonal of the S matrix for regularization.

    Returns:
    - The best expectation value and the corresponding noise level.
    """
    
    def is_valid_starting_density_matrix(rho):
        """Check if a matrix is a valid density matrix."""
        return np.allclose(np.trace(rho), 1) and np.all(np.linalg.eigvals(rho) >= 0)

    if not is_valid_starting_density_matrix(rho):
        raise ValueError("initial rho is not a valid density matrix.")
    
    def normalize_density_matrix(rho):
        """Normalize the density matrix to have a trace of 1 and non-negative eigenvalues."""
        trace_rho = np.trace(rho)
        if trace_rho == 0:
            raise ValueError("Trace of density matrix is zero, cannot normalize.")
        eigenvalues, eigenvectors = np.linalg.eigh(rho)
        eigenvalues_clipped = np.clip(eigenvalues, 0, None)
        return eigenvectors @ np.diag(eigenvalues_clipped) @ np.conj(eigenvectors.T)

    rho_normalized = normalize_density_matrix(rho)
    
    def is_valid_density_matrix(rho_normalized):
        """Check if a matrix is a valid density matrix."""
        return np.allclose(np.trace(rho_normalized), 1) and np.all(np.linalg.eigvals(rho_normalized) >= 0)

    if not is_valid_density_matrix(rho_normalized):
        raise ValueError("The normalized rho is still not a valid density matrix.")

    # Check H_matrix Hermitian 
    def is_hermitian(matrix):
        """Check if a matrix is Hermitian."""
        return np.allclose(matrix, matrix.conj().T)
    if not is_hermitian(H):
        raise ValueError("Input H is not Hermitian.")

    #A matrix set to identity as outlined in paper
    A = np.eye(rho_normalized.shape[0])

    results = []

    for level in noise_levels:
        # Applying noise and normalizing
        noisy_rho = noise_function(rho_normalized, level * stretch_factor)
        noisy_rho = normalize_density_matrix(noisy_rho)

        # Calculate H and S using the fault subspace approach
        H_matrix_noisy = np.zeros((len(noise_levels), len(noise_levels)), dtype=np.complex128)
        S_matrix_noisy = np.zeros((len(noise_levels), len(noise_levels)), dtype=np.complex128)

        for i in range(len(noise_levels)):
            for j in range(len(noise_levels)):
                sigma_i = normalize_density_matrix(noise_function(rho_normalized, noise_levels[i] * stretch_factor))
                sigma_j = normalize_density_matrix(noise_function(rho_normalized, noise_levels[j] * stretch_factor))

                cond_number = np.linalg.cond(S_matrix_noisy)
                print("Condition number of S matrix:", cond_number)
                min_eigval_S = np.min(np.linalg.eigvalsh(S_matrix_noisy))
                print("Minimum eigenvalue of S matrix:", min_eigval_S)

                H_matrix_noisy[i, j] = np.trace(sigma_i.conj().T @ sigma_j @ A @H)
                S_matrix_noisy[i, j] = np.trace(sigma_i.conj().T @ sigma_j @ A)

        # Regularize S matrix to ensure it is positive definite
        
        np.fill_diagonal(S_matrix_noisy, np.diagonal(S_matrix_noisy) + regularization_factor)
        eigvals = np.linalg.eigvalsh(S_matrix_noisy)
        if np.any(eigvals < 0):
            print("Adjusting S matrix due to negative eigenvalues.")
        regularization_factor = -np.min(eigvals) + 1e-8
        np.fill_diagonal(S_matrix_noisy, np.diagonal(S_matrix_noisy) + regularization_factor)
        cond_number = np.linalg.cond(S_matrix_noisy)
        print("Adjusted condition number of S matrix:", cond_number)


        # Solve the generalized eigenvalue problem for this subspace
        eigenvalues, eigenvectors = eigh(H_matrix_noisy, S_matrix_noisy)
        min_eigenvalue_index = np.argmin(eigenvalues)
        optimal_alpha = eigenvectors[:, min_eigenvalue_index]

        # Construct the error-mitigated density matrix
        rho_EM = sum(optimal_alpha[k] * normalize_density_matrix(noise_function(rho_normalized, noise_levels[k] * stretch_factor)) for k in range(len(noise_levels)))
        expectation_value = np.real(np.trace(rho_EM @ observable))

        # Store the results
        results.append((level, expectation_value))

    best_result = min(results, key=lambda x: abs(x[1]))
    return best_result
    
rho = np.array([[0.7, 0.3], [0.3, 0.3]])
H_matrix = np.array([[1, 0], [0, 1]])
observable = np.array([[1, 0], [0, 0]])
noise_levels = [0, 0.005, 0.0015, 0.0014, 0.006, 0.05, 0.1, 0.15, 0.2]

def noise_function(rho, noise_level):
    noise = noise_level * (np.random.normal(size=rho.shape) + 1j * np.random.normal(size=rho.shape))
    noisy_rho = rho + noise
    noisy_rho = (noisy_rho + noisy_rho.conj().T) / 2  # Symmetrize to ensure Hermitian
    eigvals, eigvecs = np.linalg.eigh(noisy_rho)
    eigvals[eigvals < 0] = 0  # Remove negative parts to maintain positive semi-definiteness
    return eigvecs @ np.diag(eigvals) @ eigvecs.conj().T

best_result = run_GSE_fault_subspace(rho, H_matrix, observable, noise_levels, noise_function)
print(f'Best noise level: {best_result[0]}, Best expectation value: {best_result[1]}')
# Out:
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.4672404223893404
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0019352740409980722
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0019352740409980722
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0019352740409980722
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0019352740409980722
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0019352740409980722
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0019352740409980722
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0019352740409980722
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0019352740409980722
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6108036675539795
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.5598651673354398
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.008310642464014069
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.008310642464014069
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.008310642464014069
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.008310642464014069
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.008310642464014069
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.008310642464014069
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.008310642464014069
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6541949854478653
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.7657684181543408
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6036065168190988
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.010625918040602825
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.010625918040602825
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.010625918040602825
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.010625918040602825
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.010625918040602825
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.010625918040602825
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6762938196822839
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.8386546971039843
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.8454315081245348
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6280662149299798
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.010876200866269843
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.010876200866269843
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.010876200866269843
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.010876200866269843
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.010876200866269843
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.7383229591142135
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9308667693894987
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9907308589984629
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9289884328727142
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6790166633885076
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.09490689866854579
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.09490689866854579
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.09490689866854579
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.09490689866854579
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.7111741196187044
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.8837824704153356
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9732092923725746
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9925375468338687
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9337244627509864
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.644120599090739
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.12535765125677312
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.12535765125677312
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.12535765125677312
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.5734410799701672
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9703242440236208
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.100071174384904
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.098816223233516
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.1446186272837064
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.1503769976062537
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9173510723307869
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.530402534525888
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.530402534525888
# Condition number of S matrix: 696.3087919636163
# Minimum eigenvalue of S matrix: -0.7014093252540441
# Condition number of S matrix: 1241.2805603192928
# Minimum eigenvalue of S matrix: -0.9043264587494161
# Condition number of S matrix: 1008.961328879644
# Minimum eigenvalue of S matrix: -1.2759863953778285
# Condition number of S matrix: 1153.697072920168
# Minimum eigenvalue of S matrix: -1.3015874319956326
# Condition number of S matrix: 1360.7205394395278
# Minimum eigenvalue of S matrix: -1.432074194302325
# Condition number of S matrix: 3038.231913576866
# Minimum eigenvalue of S matrix: -1.4990020714281405
# Condition number of S matrix: 2093.890078152494
# Minimum eigenvalue of S matrix: -1.484157403879769
# Condition number of S matrix: 13777.517231634898
# Minimum eigenvalue of S matrix: -1.0680711468971578
# Adjusting S matrix due to negative eigenvalues.
# Adjusted condition number of S matrix: 24.700885154790885
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.7002156950943823
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9156126453389988
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9566077775294933
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9102207938020009
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6546670126362217
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.038964467237800136
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.038964467237800136
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.038964467237800136
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.038964467237800136
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6017072137510653
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.7696496043503273
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.8783377593331866
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9169239881504133
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.8620291199751464
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.5997613758220937
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.11418528735906829
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.11418528735906829
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.11418528735906829
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.705625907239244
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9445343403284563
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.1903367631103186
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.2674882266705603
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.2217364331907232
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.078605050127133
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.8981406222368269
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.45957288957432774
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.45957288957432774
# Condition number of S matrix: 663.1484354108871
# Minimum eigenvalue of S matrix: -0.7740865737541461
# Condition number of S matrix: 1210.2890476570083
# Minimum eigenvalue of S matrix: -1.0445216960159687
# Condition number of S matrix: 2307.132930195057
# Minimum eigenvalue of S matrix: -1.2101479929511791
# Condition number of S matrix: 675.4898431377364
# Minimum eigenvalue of S matrix: -1.343016040523399
# Condition number of S matrix: 1395.8774836230778
# Minimum eigenvalue of S matrix: -1.317818160045275
# Condition number of S matrix: 2612.831090110072
# Minimum eigenvalue of S matrix: -1.1938696164636944
# Condition number of S matrix: 2211.756661389175
# Minimum eigenvalue of S matrix: -1.1444670829641272
# Condition number of S matrix: 3303.1183545442755
# Minimum eigenvalue of S matrix: -0.9590331866155044
# Adjusting S matrix due to negative eigenvalues.
# Adjusted condition number of S matrix: 34.41218121852203
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.4712465511141279
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.00271667907115645
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.00271667907115645
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.00271667907115645
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.00271667907115645
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.00271667907115645
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.00271667907115645
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.00271667907115645
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.00271667907115645
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6084177061470893
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.5556582614852394
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.004144759355129021
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.004144759355129021
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.004144759355129021
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.004144759355129021
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.004144759355129021
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.004144759355129021
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.004144759355129021
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.653774308530923
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.7574490181603072
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.5995796116589756
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.005016563009538345
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.005016563009538345
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.005016563009538345
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.005016563009538345
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.005016563009538345
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.005016563009538345
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.669563121941548
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.8308470204971549
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.8415287205142457
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6266324747424916
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.01026402000460189
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.01026402000460189
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.01026402000460189
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.01026402000460189
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.01026402000460189
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.68838316443345
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.8850034465177088
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9516632410957848
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9318564496217159
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6749712947053006
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0999790566325847
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0999790566325847
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0999790566325847
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0999790566325847
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.7490128879820371
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9549544635770851
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.0401958840407393
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.1026064263360427
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.0592944872910763
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.7452483900733576
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.12537134517564397
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.12537134517564397
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.12537134517564397
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.7146123864699753
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9750766408331141
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.0045347942391154
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.055042665229848
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.0865996704786203
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9509362631898763
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6864374784361968
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.13330988290558254
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.13330988290558254
# Condition number of S matrix: 1510.4772929184198
# Minimum eigenvalue of S matrix: -0.8669547097835889
# Condition number of S matrix: 1507.2523664515334
# Minimum eigenvalue of S matrix: -1.071920795825708
# Condition number of S matrix: 1559.0684349873036
# Minimum eigenvalue of S matrix: -1.107502591206075
# Condition number of S matrix: 2706.9811207073703
# Minimum eigenvalue of S matrix: -1.2706383514390007
# Condition number of S matrix: 2381.0710884946584
# Minimum eigenvalue of S matrix: -1.2475818950995219
# Condition number of S matrix: 3933.3986640537632
# Minimum eigenvalue of S matrix: -1.2344848431803728
# Condition number of S matrix: 4271.65711553279
# Minimum eigenvalue of S matrix: -1.1151794948037541
# Condition number of S matrix: 3495.880944275517
# Minimum eigenvalue of S matrix: -0.9972750974181046
# Adjusting S matrix due to negative eigenvalues.
# Adjusted condition number of S matrix: 52.4203461466312
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.46655053000820257
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6103990580976065
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.5615950309427893
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.007614959937916938
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.007614959937916938
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.007614959937916938
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.007614959937916938
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.007614959937916938
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.007614959937916938
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.007614959937916938
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6553687847730707
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.7658231532129723
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6029688912278809
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0083503200175331
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0083503200175331
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0083503200175331
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0083503200175331
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0083503200175331
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.0083503200175331
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6898402687178187
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.8560338091917513
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.8543844515001762
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6326481541135673
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.02380761065410486
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.02380761065410486
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.02380761065410486
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.02380761065410486
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.02380761065410486
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.6587751510725381
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.8133752624049445
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9041490365303914
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.8417146408175398
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.5929437472851837
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.04438769683952436
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.04438769683952436
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.04438769683952436
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.04438769683952436
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.7476953742725769
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9885606156362915
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.053883328537461
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.0428726919844533
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.9172027649522706
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.7466768828553589
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.17093057532375858
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.17093057532375858
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.17093057532375858
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.7106635077160235
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.0400603375405988
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.1076724252122634
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.1042285104469383
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.1308253997645088
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -1.0487181369282668
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.8411435048158058
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.42696842170682425
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.42696842170682425
# Condition number of S matrix: 5194.712245162591
# Minimum eigenvalue of S matrix: -0.7369785904540018
# Condition number of S matrix: 2632.011845608351
# Minimum eigenvalue of S matrix: -1.0634337351868024
# Condition number of S matrix: 1479.7884506474936
# Minimum eigenvalue of S matrix: -1.116892025199537
# Condition number of S matrix: 1577.9206838513883
# Minimum eigenvalue of S matrix: -1.1463596444243962
# Condition number of S matrix: 3365.6946751543996
# Minimum eigenvalue of S matrix: -1.2370976201651658
# Condition number of S matrix: 2592.6529643931635
# Minimum eigenvalue of S matrix: -1.1972668023040884
# Condition number of S matrix: 2164.8840696676625
# Minimum eigenvalue of S matrix: -1.0005347496825148
# Condition number of S matrix: 1346.710219630342
# Minimum eigenvalue of S matrix: -0.7440675371639567
# Adjusting S matrix due to negative eigenvalues.
# Adjusted condition number of S matrix: 34.12904038537584
# Best noise level: 0.006, Best expectation value: 67.6121644719683

# %%
# Example usage
def example_noise_model(rho, level):
    """Example noise model: Apply a simple depolarizing channel."""
    dim = rho.shape[0]
    identity = np.eye(dim) / dim
    return (1 - level) * rho + level * identity

rho = np.array([[0.7, 0.3], [0.3, 0.3]])  # Example density matrix, must be a valid quantum state
H = np.array([[1, 0], [0, 0]])  # Example Hamiltonian
observable = np.array([[1, 0], [0, 0]])  # Example observable
noise_levels = [0, 0.05, 0.1]  # Example noise levels

print('Error mitigated expectation value:', run_GSE_fault_subspace(rho, H, observable, noise_levels, example_noise_model))
# Out:
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.45809844290512797
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: 8457.064150965227
# Minimum eigenvalue of S matrix: -0.5845844620733582
# Condition number of S matrix: 9273.498585685238
# Minimum eigenvalue of S matrix: -0.5251068258250252
# Adjusted condition number of S matrix: 220436544.38346976
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.45809844290512797
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: 8457.064150965227
# Minimum eigenvalue of S matrix: -0.5845844620733582
# Condition number of S matrix: 9273.498585685238
# Minimum eigenvalue of S matrix: -0.5251068258250252
# Adjusting S matrix due to negative eigenvalues.
# Adjusted condition number of S matrix: 220436536.4125421
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: -0.45809844290512797
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: inf
# Minimum eigenvalue of S matrix: 0.0
# Condition number of S matrix: 8457.064150965227
# Minimum eigenvalue of S matrix: -0.5845844620733582
# Condition number of S matrix: 9273.498585685238
# Minimum eigenvalue of S matrix: -0.5251068258250252
# Adjusted condition number of S matrix: 220436536.4125421
# Error mitigated expectation value: (0.05, -2.0463630789890885e-11)
